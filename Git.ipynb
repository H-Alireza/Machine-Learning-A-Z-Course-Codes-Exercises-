# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Machine Learning/Machine Learning A-Z Course (Codes Exercises)
# Out:
# /content/drive/MyDrive/Colab Notebooks/Machine Learning/Machine Learning A-Z Course (Codes Exercises)

# %%
# !git config --global user.name “Alireza”
# !git config --global user.email “Aliireza_H@protonmail.com”
# !git init
# !echo "# Machine-Learning A-Z Course(Codes/Exercises)" >> README.md
# !git
